# %%
# Q1. Create a variable with your name and print it in:
# UPPERCASE, lowercase, Title Case

name = "Siddhant"
print(name)
# Write your code below:
# Out:
# Siddhant

# %%
# Q2. Create a list of 5 Indian cities
# Then:
# a) Print the 3rd city
# b) Add a new city at the end
# c) Sort the list alphabetically
# d) Print total number of cities
# Write your code below:
cities = ['Jaipur', 'Lucknow','Delhi', 'Chennai' , 'Hyderabad']   # fill this
print(cities[2])
cities.insert(5,'Prayagraj')
print(cities)
cities.sort()
print(cities)
print(len(cities))
# Out:
# Delhi
# ['Jaipur', 'Lucknow', 'Delhi', 'Chennai', 'Hyderabad', 'Prayagraj']
# ['Chennai', 'Delhi', 'Hyderabad', 'Jaipur', 'Lucknow', 'Prayagraj']
# 6

# %%
# Q3. Create a dictionary of a student with:
# Name, Age, City, Marks
# Then:
# a) Print only the keys
# b) Update the Marks to 95
# c) Add a new key "Grade" = "A"

student = {'Name': 'Rahul' , 'Age':18 , 'City':'Lucknow' , 'Marks': 98 }  # fill this
# Write your code below:
print(student.keys())
student.update({'Marks': 95})
print(student)
student.update({'Grade':'A'})
print(student)
# Out:
# dict_keys(['Name', 'Age', 'City', 'Marks'])
# {'Name': 'Rahul', 'Age': 18, 'City': 'Lucknow', 'Marks': 95}
# {'Name': 'Rahul', 'Age': 18, 'City': 'Lucknow', 'Marks': 95, 'Grade': 'A'}

# %%
# Q4. Write a function that takes a list of numbers
# and returns the AVERAGE
# Then print each number and the final average

numbers = [45, 78, 90, 55, 88, 72]

def calculate_average(nums):
    # Write your code here:
    sum=0
    for i in numbers:
        sum += i
    avg= sum/len(numbers)
    return avg
x= calculate_average(numbers)
print("Average of numbers is : ",x)
    

# Call the function and print result
# Out:
# Average of numbers is :  71.33333333333333

# %%
# Q5. Using your StudentsPerformance.csv:
# a) Load the CSV file
# b) Print first 5 rows
# c) Print the shape
# d) Print column names
# e) Print describe()
# f) Select only 'reading score' column

import pandas as pd
df = pd.read_csv('StudentsPerformance.csv')
# Write your code below: 
# print(df.head())
# print(df.shape)
# print(df.columns)
# print(df.describe)
df['gender'].head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %%
import pandas as pd
import numpy as np
# Task: Find the following using your own code:
# 1. Average math score of ALL students
# 2. Highest reading score
# 3. Lowest writing score
# 4. Total number of students
# Load the data
df = pd.read_csv('StudentsPerformance.csv')
sum_math=0
for i in df['math score']:
    sum_math += i
avg= sum_math/len(df['math score'])
print(avg)
print(df['reading score'].max())
print(df['writing score'].min())
print(len(df))
# Out:
# 66.089
# 100
# 10
# 1000
